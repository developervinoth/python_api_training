# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
list(df['LANGUAGE'].unique())
# Out:
# ['English',
#  'Spanish',
#  'French',
#  'German',
#  'Russian',
#  'Japanese',
#  'Chinese',
#  'Portuguese',
#  'Italian',
#  'Polish',
#  'Turkish',
#  'Ukrainian',
#  'Korean',
#  'Thai',
#  'Hungarian',
#  'Czech',
#  'Cantonese',
#  'Romanian',
#  'Arabic']

# %%
request_language = 'Spanish'

# %%
my_json  = df[df['LANGUAGE'] == request_language].to_json(orient='records')

# %%
my_json
# Out:
# '[{"RANK":5,"NAME":"ibai","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Just Chatting","2ND_MOST_STREAMED_GAME":"League of Legends","AVERAGE_STREAM_DURATION":4.1,"FOLLOWERS_GAINED_PER_STREAM":8.289,"AVG_VIEWERS_PER_STREAM":190.714,"AVG_GAMES_PER_STREAM":1.5,"TOTAL_TIME_STREAMED":6.865,"TOTAL_FOLLOWERS":15600000,"TOTAL_VIEWS":359000000,"TOTAL_GAMES_STREAMED":149,"ACTIVE_DAYS_PER_WEEK":4.3,"MOST_ACTIVE_DAY":"Wednesday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Saturday"},{"RANK":6,"NAME":"auronplay","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Minecraft","2ND_MOST_STREAMED_GAME":"Just Chatting","AVERAGE_STREAM_DURATION":3.7,"FOLLOWERS_GAINED_PER_STREAM":13.26,"AVG_VIEWERS_PER_STREAM":213.849,"AVG_GAMES_PER_STREAM":1.8,"TOTAL_TIME_STREAMED":4.482,"TOTAL_FOLLOWERS":16300000,"TOTAL_VIEWS":263000000,"TOTAL_GAMES_STREAMED":169,"ACTIVE_DAYS_PER_WEEK":5.0,"MOST_ACTIVE_DAY":"Wednesday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Sunday"},{"RANK":15,"NAME":"illojuan","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Just Chatting","2ND_MOST_STREAMED_GAME":"Minecraft","AVERAGE_STREAM_DURATION":4.5,"FOLLOWERS_GAINED_PER_STREAM":2.993,"AVG_VIEWERS_PER_STREAM":52.631,"AVG_GAMES_PER_STREAM":1.7,"TOTAL_TIME_STREAMED":7.382,"TOTAL_FOLLOWERS":4090000,"TOTAL_VIEWS":72000000,"TOTAL_GAMES_STREAMED":368,"ACTIVE_DAYS_PER_WEEK":4.5,"MOST_ACTIVE_DAY":"Thursday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Sunday"},{"RANK":38,"NAME":"kingsleagueamericas","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Sports","2ND_MOST_STREAMED_GAME":"Fortnite","AVERAGE_STREAM_DURATION":3.4,"FOLLOWERS_GAINED_PER_STREAM":13.617,"AVG_VIEWERS_PER_STREAM":0.0,"AVG_GAMES_PER_STREAM":1.0,"TOTAL_TIME_STREAMED":134.0,"TOTAL_FOLLOWERS":467000,"TOTAL_VIEWS":0,"TOTAL_GAMES_STREAMED":3,"ACTIVE_DAYS_PER_WEEK":1.3,"MOST_ACTIVE_DAY":"Sunday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Wednesday"},{"RANK":39,"NAME":"mixwell","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"VALORANT","2ND_MOST_STREAMED_GAME":"Counter-Strike","AVERAGE_STREAM_DURATION":4.8,"FOLLOWERS_GAINED_PER_STREAM":1.124,"AVG_VIEWERS_PER_STREAM":27.368,"AVG_GAMES_PER_STREAM":1.1,"TOTAL_TIME_STREAMED":4.432,"TOTAL_FOLLOWERS":1090000,"TOTAL_VIEWS":26400000,"TOTAL_GAMES_STREAMED":42,"ACTIVE_DAYS_PER_WEEK":2.3,"MOST_ACTIVE_DAY":"Sunday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Sunday"},{"RANK":43,"NAME":"desst3","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Grand Theft Auto V","2ND_MOST_STREAMED_GAME":"Minecraft","AVERAGE_STREAM_DURATION":5.6,"FOLLOWERS_GAINED_PER_STREAM":464.0,"AVG_VIEWERS_PER_STREAM":10.358,"AVG_GAMES_PER_STREAM":1.3,"TOTAL_TIME_STREAMED":7.586,"TOTAL_FOLLOWERS":574000,"TOTAL_VIEWS":12800000,"TOTAL_GAMES_STREAMED":44,"ACTIVE_DAYS_PER_WEEK":5.1,"MOST_ACTIVE_DAY":"Friday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Tuesday"},{"RANK":50,"NAME":"rubius","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Just Chatting","2ND_MOST_STREAMED_GAME":"Minecraft","AVERAGE_STREAM_DURATION":4.7,"FOLLOWERS_GAINED_PER_STREAM":11.592,"AVG_VIEWERS_PER_STREAM":212.445,"AVG_GAMES_PER_STREAM":3.1,"TOTAL_TIME_STREAMED":6.806,"TOTAL_FOLLOWERS":15000000,"TOTAL_VIEWS":273000000,"TOTAL_GAMES_STREAMED":616,"ACTIVE_DAYS_PER_WEEK":5.0,"MOST_ACTIVE_DAY":"Sunday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Wednesday"},{"RANK":61,"NAME":"nexxuz","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Grand Theft Auto V","2ND_MOST_STREAMED_GAME":"World of Warcraft","AVERAGE_STREAM_DURATION":4.5,"FOLLOWERS_GAINED_PER_STREAM":6.163,"AVG_VIEWERS_PER_STREAM":11.542,"AVG_GAMES_PER_STREAM":1.5,"TOTAL_TIME_STREAMED":248.0,"TOTAL_FOLLOWERS":335000,"TOTAL_VIEWS":759000,"TOTAL_GAMES_STREAMED":11,"ACTIVE_DAYS_PER_WEEK":0.2,"MOST_ACTIVE_DAY":"Tuesday","DAY_WITH_MOST_FOLLOWERS_GAINED":"Sunday"},{"RANK":66,"NAME":"elmariana","LANGUAGE":"Spanish","TYPE":"personality","MOST_STREAMED_GAME":"Just Chatting","2ND_MOST_STREAMED_GAME":"Minecraft","AVERAGE_STREAM_DURATION":3.7,"FOLLOWERS_GAINED_PER_STREAM ...
