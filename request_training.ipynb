# %%
import requests
import pandas as pd

# %%
get_example = requests.get("http://127.0.0.1:8000/languages").json()

# %%
body_params = {"get_language":"Spanish"}

# %%
my_data = requests.post('http://127.0.0.1:8000/custom-language/', json = body_params).json()

# %%
pd.read_json(my_data)
# Out:
# C:\Users\Vinoth\AppData\Local\Temp\ipykernel_33644\3757372771.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(my_data)
#      RANK                 NAME LANGUAGE         TYPE  MOST_STREAMED_GAME  \
# 0       5                 ibai  Spanish  personality       Just Chatting
# 1       6            auronplay  Spanish  personality           Minecraft
# 2      15             illojuan  Spanish  personality       Just Chatting
# 3      38  kingsleagueamericas  Spanish  personality              Sports
# 4      39              mixwell  Spanish  personality            VALORANT
# ..    ...                  ...      ...          ...                 ...
# 101   936      chiringuitovivo  Spanish  personality              Sports
# 102   954           menostrece  Spanish  personality    Dead by Daylight
# ...
